# %%
## Importing the Necessary Libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # visualization
import seaborn as sns # visualization
import cv2
import tensorflow as tf 
from tensorflow import keras
from pathlib import Path
import PIL
import os
from tqdm import tqdm

## Load the Dataset
folder_path = 'P:/EDI/dataset'

# Create paths for all diseases
diseases = ['diabetic_retinopathy', 'normal', 'cataract', 'glaucoma', 'hypertension', 'macular', 'pathological_myopia']
df = pd.DataFrame()

# Build the dataframe
for disease in diseases:
    disease_path = Path(folder_path) / disease
    for imagepath in tqdm(list(disease_path.iterdir()), desc=str(disease)):
        df = pd.concat([df, pd.DataFrame({'image': [str(imagepath)], 'disease_type': [disease]})], ignore_index=True)

# Visualizing the number of images per disease
sns.countplot(y='disease_type', data=df)
plt.xlabel('Number of Images')
plt.ylabel('Disease Type')
plt.title('Distribution of Images in Dataset')
plt.show()

## Shuffling the rows of DataFrame
df1 = df.sample(frac=1).reset_index(drop=True)

## Data Training & Testing
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet50 import preprocess_input

datagen = ImageDataGenerator(preprocessing_function=preprocess_input, validation_split=0.2, rescale=1./255.)

# Data generators for training 
train_data = datagen.flow_from_dataframe(dataframe=df1,
                                          x_col='image',
                                          y_col='disease_type',
                                          target_size=(224, 224),
                                          class_mode='categorical',
                                          batch_size=32,
                                          shuffle=True,
                                          subset='training')

# Data generators for validation
valid_data = datagen.flow_from_dataframe(dataframe=df1,
                                          x_col='image',
                                          y_col='disease_type',
                                          target_size=(224, 224),
                                          class_mode='categorical',
                                          batch_size=32,
                                          shuffle=False,
                                          subset='validation')

## Building the Models (VGG19, ResNet50, InceptionV3)
from tensorflow.keras.applications import VGG19, ResNet50, InceptionV3
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense

# Function to create model
def create_model(base_model):
    model = Sequential()
    model.add(base_model)
    model.add(Flatten())
    model.add(Dense(len(diseases), activation="softmax"))  # Updated to match number of diseases
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# VGG19 Model
vgg_base = VGG19(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
for layer in vgg_base.layers:
    layer.trainable = False
vgg_model = create_model(vgg_base)
vgg_model.summary()

# ResNet50 Model
resnet_base = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
for layer in resnet_base.layers:
    layer.trainable = False
resnet_model = create_model(resnet_base)
resnet_model.summary()

# InceptionV3 Model
inception_base = InceptionV3(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
for layer in inception_base.layers:
    layer.trainable = False
inception_model = create_model(inception_base)
inception_model.summary()

## Training the Models
# Train VGG19
vgg_history = vgg_model.fit(train_data, epochs=15, validation_data=valid_data, verbose=1)

# Train ResNet50
resnet_history = resnet_model.fit(train_data, epochs=15, validation_data=valid_data, verbose=1)

# Train InceptionV3
inception_history = inception_model.fit(train_data, epochs=15, validation_data=valid_data, verbose=1)

## Plot Training History
def plot_history(history, model_name):
    plt.figure(figsize=(12, 5))

    # Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='train_accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.title(f'{model_name} Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='train_loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.title(f'{model_name} Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.show()

plot_history(vgg_history, 'VGG19')
plot_history(resnet_history, 'ResNet50')
plot_history(inception_history, 'InceptionV3')

## Evaluate the Models
vgg_eval = vgg_model.evaluate(valid_data)
resnet_eval = resnet_model.evaluate(valid_data)
inception_eval = inception_model.evaluate(valid_data)

print(f"VGG19 Validation Accuracy: {vgg_eval[1]:.4f}")
print(f"ResNet50 Validation Accuracy: {resnet_eval[1]:.4f}")
print(f"InceptionV3 Validation Accuracy: {inception_eval[1]:.4f}")

## Generate a Classification Report
from sklearn.metrics import classification_report

def classification_report_for_model(model, valid_data):
    valid_data.reset()
    predictions = model.predict(valid_data)
    y_pred = np.argmax(predictions, axis=1)
    y_true = valid_data.classes
    print(classification_report(y_true, y_pred, target_names=list(valid_data.class_indices.keys())))

print("Classification report for VGG19 model")
classification_report_for_model(vgg_model, valid_data)

print("---------------------------------------------------")
print("Classification report for ResNet50 model")
classification_report_for_model(resnet_model, valid_data)

print("---------------------------------------------------")
print("Classification report for InceptionV3 model")
classification_report_for_model(inception_model, valid_data)
# Out:
# ...
# pathological_myopia: 100%|█████████████████████████████████████████████████████████| 111/111 [00:00<00:00, 4076.06it/s]
# Found 3761 validated image filenames belonging to 7 classes.
# Found 940 validated image filenames belonging to 7 classes.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ vgg19 (Functional)                   │ (None, 7, 7, 512)           │      20,024,384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 7)                   │         175,623 │
# ...

# %%
## Testing the Models on New Data

# Load and preprocess a single image
def load_and_preprocess_image(image_path):
    # Load the image
    img = PIL.Image.open(image_path)
    # Resize the image to (224, 224) for model input
    img = img.resize((224, 224))
    # Convert the image to a NumPy array and preprocess
    img_array = np.array(img)
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    img_array = img_array.astype('float32')
    img_array /= 255.0  # Rescale pixel values
    return img_array

# Function to test the model on a new image
def test_model(model, image_path):
    # Load and preprocess the image
    processed_image = load_and_preprocess_image(image_path)
    # Predict the class
    prediction = model.predict(processed_image)
    # Get the predicted class label
    predicted_class_index = np.argmax(prediction, axis=1)[0]
    predicted_class = list(train_data.class_indices.keys())[predicted_class_index]
    print(f"Predicted Disease Type: {predicted_class}")

# Example of using the test function with VGG19, ResNet50, and InceptionV3 models
test_image_path = 'P:/EDI/dataset/macular/319_left.jpg'  # Replace with your image path

print("VGG19 Model Prediction:")
test_model(vgg_model, test_image_path)

print("---------------------------------------------------")

print("ResNet50 Model Prediction:")
test_model(resnet_model, test_image_path)

print("---------------------------------------------------")

print("InceptionV3 Model Prediction:")
test_model(inception_model, test_image_path)
# Out:
# VGG19 Model Prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Predicted Disease Type: normal
# ---------------------------------------------------
# ResNet50 Model Prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Predicted Disease Type: diabetic_retinopathy
# ---------------------------------------------------
# InceptionV3 Model Prediction:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Predicted Disease Type: hypertension

# %%
from collections import Counter
from scipy import stats

# Function for majority voting prediction
def majority_voting(models, image_path):
    predictions = []
    
    # Get predictions from all models
    for model in models:
        prediction = get_prediction_from_model(model, image_path)
        predictions.append(prediction)
    
    # Debug: Print out the predictions list
    print(f"Predictions from all models: {predictions}")
    
    # Use Counter for majority voting to get the final prediction
    prediction_counts = Counter(predictions)
    
    # Debug: Print out the prediction counts
    print(f"Prediction counts: {prediction_counts}")
    
    # Get the most common prediction
    majority_vote = prediction_counts.most_common(1)[0][0]
    
    # Get the predicted class label from the index
    predicted_class = list(train_data.class_indices.keys())[majority_vote]
    
    return predicted_class

# Models to test
models = [vgg_model, resnet_model, inception_model]

# Image path for testing
test_image_path = 'P:/EDI/dataset/pathological_myopia/35_left.jpg'  # Replace with your image path

# Perform majority voting
final_prediction = majority_voting(models, test_image_path)
print(f"Final Predicted Disease Type (Majority Vote): {final_prediction}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Predictions from all models: [2, 6, 6]
# Prediction counts: Counter({6: 2, 2: 1})
# Final Predicted Disease Type (Majority Vote): pathological_myopia

# %%
# Save the VGG19 model in the new Keras format
vgg_model.save('vgg19_model.keras')

# Save the ResNet50 model in the new Keras format
resnet_model.save('resnet50_model.keras')

# Save the InceptionV3 model in the new Keras format
inception_model.save('inceptionv3_model.keras')

# %%
## Importing Necessary Libraries
import numpy as np  # linear algebra
import pandas as pd  # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt  # visualization
import seaborn as sns  # visualization
from pathlib import Path
from tqdm import tqdm

## Load the Dataset
folder_path = 'P:/EDI/dataset'

# Create paths for all diseases
diseases = ['diabetic_retinopathy', 'normal', 'cataract', 'glaucoma', 'hypertension', 'macular', 'pathological_myopia']
df = pd.DataFrame()

# Build the dataframe
for disease in diseases:
    disease_path = Path(folder_path) / disease
    for imagepath in tqdm(list(disease_path.iterdir()), desc=str(disease)):
        df = pd.concat([df, pd.DataFrame({'image': [str(imagepath)], 'disease_type': [disease]})], ignore_index=True)

# Visualizing the number of images per disease
plt.figure(figsize=(10, 6))
sns.countplot(y='disease_type', data=df)
plt.xlabel('Number of Images')
plt.ylabel('Disease Type')
plt.title('Distribution of Images in Dataset')
plt.show()

## Shuffling the rows of DataFrame
df1 = df.sample(frac=1).reset_index(drop=True)
# Out:
# ...
# pathological_myopia: 100%|█████████████████████████████████████████████████████████| 111/111 [00:00<00:00, 3883.78it/s]

# %%
# Collecting results into a dictionary
results = {
    "Model": ["VGG-19", "ResNet-50", "InceptionV3"],
    "Training Accuracy (%)": [max(vgg_history.history['accuracy']) * 100, 
                              max(resnet_history.history['accuracy']) * 100, 
                              max(inception_history.history['accuracy']) * 100],
    "Training Loss": [min(vgg_history.history['loss']), 
                      min(resnet_history.history['loss']), 
                      min(inception_history.history['loss'])],
    "Validation Accuracy (%)": [vgg_eval[1] * 100, 
                                resnet_eval[1] * 100, 
                                inception_eval[1] * 100],
    "Validation Loss": [vgg_eval[0], resnet_eval[0], inception_eval[0]],
}

# Create a DataFrame
results_df = pd.DataFrame(results)

# Display the DataFrame
print(results_df)

# Optional: To plot the results as a table
plt.figure(figsize=(8, 4))
plt.axis('off')
table = plt.table(cellText=results_df.values, 
                  colLabels=results_df.columns, 
                  cellLoc='center', 
                  loc='center')
table.auto_set_font_size(False)
table.set_fontsize(12)
table.scale(1.2, 1.2)
plt.show()
# Out:
#          Model  Training Accuracy (%)  Training Loss  Validation Accuracy (%)  \
# 0       VGG-19              93.485773       0.171298                87.659574
# 1    ResNet-50              65.913320       0.982194                71.595746
# 2  InceptionV3              98.856688       0.064626                85.212767
#
#    Validation Loss
# 0         0.374608
# 1         1.046749
# 2         1.541678
